# %% [markdown]
# # DSA 4202 Assignment 2: Predictive Modeling with Linear Methods
#
# This companion notebook records the workflow used to generate the submission PDF.

# %%
# Data sources
no_show_url = "public raw CSV mirror of Kaggle no-show appointments"
concrete_url = "official UCI concrete compressive strength archive"

# %% [markdown]
# ## Results Summary

# %% [markdown]
# Medical appointment classification: Logistic Regression F1=0.408, Linear SVC F1=0.397.
#
# Concrete regression: Ridge RMSE=9.687, Lasso RMSE=9.693.

# %%
# Core modeling choices
# - Standardized all model features.
# - Tuned regularization strength with a small validation-style grid.
# - Used class weights for the no-show target imbalance.
# - Compared Ridge/Lasso for regression and Logistic/SVC for classification.
